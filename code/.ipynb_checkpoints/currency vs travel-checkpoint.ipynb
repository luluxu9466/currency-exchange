# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Import currency and travel csv
data_path = "../data_cleaning/"
currency_data = pd.read_csv(data_path + "forex_data.csv")
travel_data = pd.read_csv(data_path + "cleaned_travel_expenditures.csv")
trip_data = pd.read_csv(data_path + "trips.csv")

# Format date in yyyy-mm-dd
travel_data["Date"] = pd.to_datetime(travel_data["Date"])
currency_data["Date"] = pd.to_datetime(currency_data["Date"])
trip_data["Date"] = pd.to_datetime(trip_data["Date"])

travel_data = travel_data.drop(["Unnamed: 0"], axis=1)
currency_data = currency_data.drop(["Unnamed: 0", "Unnamed: 0.1"], axis=1)
# currency_data = currency_data.set_index("currency")

usa_currency = currency_data.loc[currency_data['currency'] == 'USD']

combined_data = pd.merge(travel_data, usa_currency, on=["Date"])
combined_data = pd.merge(combined_data, trip_data, on=["Date"])

combined_data
# Out:
#           Date Expenditures  Year_x  Month_x               Rate currency  \
# 0   2005-01-01   $1,620.00     2005        1  {'USD': 1.358363}      USD
# 1   2005-02-01   $1,768.00     2005        2  {'USD': 1.303526}      USD
# 2   2005-03-01   $1,844.00     2005        3  {'USD': 1.319134}      USD
# 3   2005-04-01   $1,987.00     2005        4  {'USD': 1.291129}      USD
# 4   2005-05-01   $1,901.00     2005        5  {'USD': 1.291002}      USD
# 5   2005-06-01   $1,816.00     2005        6  {'USD': 1.221849}      USD
# 6   2005-07-01   $1,721.00     2005        7  {'USD': 1.197754}      USD
# 7   2005-08-01   $1,697.00     2005        8  {'USD': 1.220408}      USD
# 8   2005-09-01   $1,580.00     2005        9   {'USD': 1.24598}      USD
# 9   2005-10-01   $1,640.00     2005       10  {'USD': 1.202987}      USD
# 10  2005-11-01   $1,398.00     2005       11  {'USD': 1.200047}      USD
# 11  2005-12-01   $1,686.00     2005       12   {'USD': 1.17252}      USD
# 12  2006-01-01   $1,937.00     2006        1  {'USD': 1.181562}      USD
# 13  2006-02-01   $1,402.00     2006        2  {'USD': 1.207546}      USD
# 14  2006-03-01   $1,371.00     2006        3  {'USD': 1.191541}      USD
# 15  2006-04-01   $1,519.00     2006        4  {'USD': 1.210966}      USD
# 16  2006-05-01   $1,543.00     2006        5  {'USD': 1.259103}      USD
# 17  2006-06-01   $1,575.00     2006        6  {'USD': 1.279718}      USD
# 18  2006-07-01   $1,914.00     2006        7  {'USD': 1.275026}      USD
# 19  2006-08-01   $2,007.00     2006        8  {'USD': 1.279399}      USD
# 20  2006-09-01   $1,880.00     2006        9  {'USD': 1.283005}      USD
# 21  2006-10-01   $1,559.00     2006       10  {'USD': 1.266873}      USD
# 22  2006-11-01   $1,559.00     2006       11  {'USD': 1.276621}      USD
# 23  2006-12-01   $1,663.00     2006       12  {'USD': 1.331278}      USD
# 24  2007-01-01   $2,037.00     2007        1  {'USD': 1.315192}      USD
# 25  2007-02-01   $1,857.00     2007        2   {'USD': 1.30208}      USD
# 26  2007-03-01   $2,291.00     2007        3  {'USD': 1.319312}      USD
# 27  2007-04-01   $2,035.00     2007        4  {'USD': 1.333632}      USD
# 28  2007-05-01   $2,404.00     2007        5  {'USD': 1.360987}      USD
# 29  2007-06-01   $2,573.00     2007        6  {'USD': 1.344044}      USD
# ..         ...          ...     ...      ...                ...      ...
# 90  2012-07-01   $5,751.00     2012        7   {'USD': 1.26272}      USD
# 91  2012-08-01   $6,441.00     2012        8  {'USD': 1.226112}      USD
# 92  2012-09-01   $6,071.00     2012        9  {'USD': 1.257741}      USD
# 93  2012-10-01   $5,744.00     2012       10  {'USD': 1.288902}      USD
# 94  2012-11-01   $6,226.00     2012       11  {'USD': 1.294038}      USD
# 95  2012-12-01   $6,322.00     2012       12  {'USD': 1.298858}      USD
# 96  2013-01-01   $7,019.00     2013        1  {'USD': 1.320739}      USD
# 97  2013-02-01   $7,042.00     2013        2  {'USD': 1.365048}      USD
# 98  2013-03-01   $7,088.00     2013        3  {'USD': 1.302658}      USD
# 99  2013-04-01   $7,362.00     2013        4   {'USD': 1.28358}      USD
# 100 2013-05-01   $7,270.00     2013        5  {'USD': 1.318364}      USD
# 101 2013-06-01   $7,351.00     2013        6  {'USD': 1.299039}      USD
# 102 2013-07-01   $7,725.00     2013        7  {'USD': 1.305805}      USD
# 103 2013-08-01   $7,223.00     2013        8  {'USD': 1.321978}      USD
# 104 2013-09-01   $7,451.00     2013        9  {'USD': 1.321002}      USD
# 105 2013-10-01   $7,549.00     2013       10  {'USD': 1.352404}      USD
# 106 2013-11-01   $7,538.00     2013       11  {'USD': 1.354335}      USD
# 107 2013-12-01   $7,734.00     2013       12  {'USD': 1.359019}      USD
# 108 2014-01-01   $7,646.00     2014        1  {'USD': 1.375574}      USD
# 109 2014-02-01   $7,742.00     2014        2  {'USD': 1.348849}      USD
# 110 2014-03-01   $7,480.00     2014        3  {'USD': 1.380188}      USD
# 111 2014-04-01   $7,692.00     2014        4  {'USD': 1.379373}      USD
# 112 2014-05-01   $7,871.00     2014        5  {'USD': 1.386913}      USD
# 113 2014-06-01   $7,826.00     2014        6  {'USD': 1.362788}      USD
# 114 2014-07-01   $8,047.00     2014        7  {'USD': 1.367914}      USD
# 115 2014-08-01   $8,142.00     2014        8  {'USD': 1.342868}      USD
# 116 2014-09-01   $8,392.00     2014        9  {'USD': 1.312927}      USD
# 117 2014-10-01   $8,234.00     2014       10  {'USD': 1.261914}      USD
# 118 2014-11-01   $8,163.00     2014       11  {'USD': 1.252477}      USD
# 119 2014-12-01   $8,197.00     2014       12  {'USD': 1.247301}      USD
#
#          rate  year  month month_str  Year_y  Month_y   outbound    inbound
# 0    1.358363  2005      1       Jan    2005        1    748,042    599,534
# 1    1.303526  2005      2       Feb    2005        2    649,274    705,107
# 2    1.319134  2005      3       Mar    2005        3    992,917    927,050
# 3    1.291129  2005      4       Apr    2005        4    944,616    898,956
# 109  1.348849  2014      2       Feb    2014        2    497,003     822740
# 110  1.380188  2014      3       Mar    2014        3    806,663    1026602
# 111  1.379373  2014      4       Apr    2014        4    868,367    1404389
# 112  1.386913  2014      5       May    2014        5  1,305,842    1231200
# 113  1.362788  2014      6      June    2014        6  1,614,486    1220711
# 114  1.367914  2014      7      July    2014        7  1,413,798    1501021
# 115  1.342868  2014      8    August    2014        8  1,185,907    1520112
# 116  1.312927  2014      9      Sept    2014        9  1,241,537    1303021
# 117  1.261914  2014     10       Oct    2014       10    915,090    1394568
# 118  1.252477  2014     11       Nov    2014       11    675,275     999496
# 119  1.247301  2014     12       Dec    2014       12    790,557    1094494
#
# [120 rows x 14 columns]

# %%
# Set x and y axises
x_axis = combined_data["rate"]
expenditure = combined_data["Expenditures"].str.strip("$")
expenditure = expenditure.str.replace(',', '')
expenditure = expenditure.astype(float)/combined_data["rate"]
y_axis = expenditure

# Plot scatter graph for currency rate vs. travel expenditure
plt.scatter(x_axis, y_axis, c="red", edgecolor="black")

# Set plot title, x-axis and y-axis labels
plt.title("Currency Rates vs. Travel Expenditures in the USA (Corr=0.04688903)")
plt.xlabel("Currency Rate (to EUR)")
plt.ylabel("Travel Expenditure (EUR)")

# Add grids
plt.grid()

# Save figure
plt.savefig("../graphs/currency vs. travel expenditure.png")

# Show the chart
plt.show()

# %%
# Calculate the correlation between USD currency rate and travel expenditures
np.corrcoef(x_axis, y_axis)
# Out:
# array([[1.        , 0.04688903],
#        [0.04688903, 1.        ]])

# %%
# Set x and y axises
departure = combined_data["outbound"]
departure = departure.str.replace(',', '')
departure = departure.astype(float)

# Plot scatter graph for currency rate vs. travel expenditure
plt.scatter(x_axis, departure, edgecolor="black")

# Set plot title, x-axis and y-axis labels
plt.title("Currency Rates vs. Traveling from the USA (Corr=0.01860821)")
plt.xlabel("Currency Rate (to EUR)")
plt.ylabel("Travel Outbound")

# Add grids
plt.grid()

# Save figure
plt.savefig("../graphs/currency vs. travel outbound.png")

# Show the chart
plt.show()

# %%
# Calculate the correlation between USD currency rate and travel outbound
np.corrcoef(x_axis, departure)
# Out:
# array([[1.        , 0.01860821],
#        [0.01860821, 1.        ]])

# %%
# Set x and y axises
arrival = combined_data["inbound"]
arrival = arrival.str.replace(',', '')
arrival = arrival.astype(float)

# Plot scatter graph for currency rate vs. travel expenditure
plt.scatter(x_axis, arrival, edgecolor="black", c= "green")

# Set plot title, x-axis and y-axis labels
plt.title("Currency Rates vs. Traveling to the USA (Corr=0.19802362)")
plt.xlabel("Currency Rate (to EUR)")
plt.ylabel("Travel Inbound")

# Add grids
plt.grid()

# Save figure
plt.savefig("../graphs/currency vs. travel inbound.png")

# Show the chart
plt.show()

# %%
# Calculate the correlation between USD currency rate and travel inbound
np.corrcoef(x_axis, arrival)
# Out:
# array([[1.        , 0.19802362],
#        [0.19802362, 1.        ]])
